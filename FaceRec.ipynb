# %%
import os
import cv2
import imutils
from imutils import paths
import numpy as np
from PIL import Image

# %% [markdown]
# Let's now define some paths for the data

# %%
current_dir = os.getcwd()
data_dir = os.path.join(current_dir, 'data')
test_dir = os.path.join(current_dir, 'data_test')

detector_dir = os.path.join(current_dir, 'detector')
detector_protoPath = os.path.join(detector_dir, 'deploy.prototxt')
detector_modelPath = os.path.join(detector_dir, 'res10_300x300_ssd_iter_140000.caffemodel')

embedder_dir = os.path.join(current_dir, 'embedder')
embedder_modelPath = os.path.join(embedder_dir, 'openface_nn4.small2.v1.t7')

# %%
current_dir
# Out:
# 'C:\\Users\\gheor'
